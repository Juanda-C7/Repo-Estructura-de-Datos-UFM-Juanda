# %% [markdown]
#  ## Parcial II - Estructuras de Datos
# ---
#
# -Juan David Contreras-
# -20240554-

# %% [markdown]
# ### **Instrucciones:**
#
# Desarrolle su parcial en este notebook según las indicaciones en las siguientes celdas. Trabaje de forma ordenada y asegúrese que el notebook corra exitosamente antes de entregarlo (`clear all outputs` -> `restart` kernel -> `run all`). De esta misma manera se calificará su parcial. Un notebook que presente problemas en el `run all` será considerado inválido.

# %% [markdown]
# #### **1 - Binary Search Tree**
# ---
#
# 1.1 - En el archivo `bst.py`, agregue la clase de BST desarrollada en clase. Asegúrese de incluir el método *pretty_print()*.
#
# 1.2 - Instanciar un BST y agregar 25 elementos cualesquiera. Luego, demostrar que las operaciones de *insert()*, *delete()* y *search()* funcionan como esperado en un Binary Search Tree. Dejar constancia de cada una de estas operaciones con el método *pretty_print()*.

# %%
from bst import BinarySearchTree

# %%
tree = BinarySearchTree()

# %%
# Espacio para inciso 1.2 (utilizar cuantas celdas de código sean necesarias)
vals = [12,17,14,5,72,75,80,88,21,22,27,30,49,58,61,63,33,36,39,42,47,66,93,95,99] 


for val in vals:
    tree.insert(val)
    
tree.print_pretty()
# Out:
#  12___
# /     \
# 5    17_____________________________
#     /                               \
#    14    __________________________72_
#         /                             \
#        21_                           75_
#           \                             \
#          22_                           80_
#             \                             \
#            27_                           88_
#               \                             \
#              30___________                 93_
#                           \                   \
#                  ________49_                 95_
#                 /           \                   \
#                33_         58_                 99
#                   \           \
#                  36_         61_
#                     \           \
#                    39_         63_
#                       \           \
#                      42_         66
#                         \
#                        47

# %%
#insert
tree.insert(3)
tree.insert(97)
tree.insert(85)
tree.print_pretty()
# Out:
#   12___
#  /     \
#  5    17_____________________________
# /    /                               \
# 3   14    __________________________72_
#          /                             \
#         21_                           75_
#            \                             \
#           22_                           80___
#              \                               \
#             27_                             88_
#                \                           /   \
#               30___________               85  93_
#                            \                     \
#                   ________49_                   95___
#                  /           \                       \
#                 33_         58_                     99
#                    \           \                   /
#                   36_         61_                 97
#                      \           \
#                     39_         63_
#                        \           \
# ...

# %%
#delete
tree.delete(22)
tree.delete(61)
tree.print_pretty()
# Out:
#   12___
#  /     \
#  5    17_________________________
# /    /                           \
# 3   14    ______________________72_
#          /                         \
#         21_                       75_
#            \                         \
#           27_                       80___
#              \                           \
#             30___________               88_
#                          \             /   \
#                 ________49_           85  93_
#                /           \                 \
#               33_         58_               95___
#                  \           \                   \
#                 36_         63_                 99
#                    \           \               /
#                   39_         66              97
#                      \
#                     42_
#                        \
#                       47

# %%
#search
tree.search(49)
# Out:
# True

# %% [markdown]
# #### **2 - AVL Tree**
# ---
#
# 2.1 - En el archivo `avl.py`, crear una clase que implemente un árbol AVL. Esta clase puede ser implementada desde cero o generada con AI. Considerar que:
# - La clase debe estar explícitamente declarada en el `avl.py`, ya que debe incluir el método de *pretty_print()*. Esto imposibilita el uso de alguna librería de python que contenga una implementación de AVL.
# - Si utiliza AI para generar la clase, debe documentar en este notebook el prompt utilizado, ya sea en las celdas correspondientes al inciso o en un apartado de Anexos.
#
# 2.2 - Instanciar un AVL y agregar 25 elementos cualesquiera. Luego, demostrar que las operaciones de *insert()*, *delete()* y *search()* funcionan como esperado en un árbol AVL. Dejar constancia de cada una de estas operaciones con el método *pretty_print()*.

# %% [markdown]
# Promt: Necesito que me crees una clase entera de un AVL tree en python, con todas la operaciones necesarias (search, insert, delete). También incluye una función de print_pretty, que se encargue de imprimir el arbol de forma que se visualize como se suelen representar los arboles

# %%
from avl import AVLTree

# %%
avl = AVLTree()

# %%
# Espacio para inciso 2.2 (utilizar cuantas celdas de código sean necesarias)
vals = [12,17,14,5,72,75,80,88,21,22,27,30,49,58,61,63,33,36,39,42,47,66,93,95,99]


for val in vals:
    avl.insert(val)


avl.print_pretty()
# Out:
#          ______33_________
#         /                 \
#      __21___         ____49_________
#     /       \       /               \
#    14_     27_     39_         ____72_______
#   /   \   /   \   /   \       /             \
#  12  17  22  30  36  42_     61_         __93_
# /                       \   /   \       /     \
# 5                      47  58  63_     80_   95_
#                                   \   /   \     \
#                                  66  75  88    99

# %%
#insert
avl.insert(3)
avl.insert(97)
avl.insert(85)
avl.print_pretty()
# Out:
#           ______33___________________
#          /                           \
#       __21___               ________72_________
#      /       \             /                   \
#   __14_     27_       ____49___           ____93___
#  /     \   /   \     /         \         /         \
#  5_   17  22  30    39_       61_       80___     97_
# /  \               /   \     /   \     /     \   /   \
# 3 12              36  42_   58  63_   75    88  95  99
#                          \         \       /
#                         47        66      85

# %%
#delete
avl.delete(14)
avl.delete(33)
avl.print_pretty()
# Out:
#         ______36_________________
#        /                         \
#   ____21___             ________72_________
#  /         \           /                   \
#  5___     27_       __49___           ____93___
# /    \   /   \     /       \         /         \
# 3   17  22  30    42_     61_       80___     97_
#    /             /   \   /   \     /     \   /   \
#   12            39  47  58  63_   75    88  95  99
#                                \       /
#                               66      85

# %%
#search
avl.search(72)
# Out:
# True

# %% [markdown]
# #### **3 - Evaluación de Complejidad**
# ---

# %%
import time

def time_function(func, *args, **kwargs):
    start_time = time.perf_counter()
    result = func(*args, **kwargs)
    end_time = time.perf_counter()
    duration = end_time - start_time
    print(f'Execution time: {duration:.10f} secs')
    return duration

# Example usage:
def sample_function(n):
    # Sample function that calculates the sum of numbers from 0 to n-1
    return sum(range(n))

# Time the sample_function execution with argument 1000000
result = time_function(sample_function, 1000000)

# Ejemplo con clase de BST:
#insert_time = time_function(tree.insert, 42)
# Out:
# Execution time: 0.0101741000 secs

# %% [markdown]
# 3.1.a - Instanciar un nuevo objeto **BST** e insertar **5K nodos**. Los valores de dichos nodos deben diseñarse con el objetivo de generar un árbol con la peor topología posible (desde la perspectiva de complejidad temporal).
#
# 3.1.b - Instanciar un nuevo objeto **AVL** e insertar **5K nodos**. Agregar exactamente los valores utilizados en el inciso anterior.

# %%
# Espacio para inciso 3.1 

import sys
sys.setrecursionlimit(30000)

# %%
#3.1a
bst5k = BinarySearchTree()
for i in range(1, 5001):
    bst5k.insert(i)

# %%
#3.1b
avlt5k = AVLTree()
for i in range(1,5001):
    avlt5k.insert(i)

# %% [markdown]
# ##### **Insert()**
#
# Al inicio del inciso *3* se encuentra la función `time_function` junto a un ejemplo de su uso. Esta función permite perfilar el **tiempo** en segundos que toma ejecutar una función y devuelve el resultado con una precisión de diez decimales. Utilice esta función para perfilar el tiempo en los siguientes incisos que lo requieran.
#
# 3.2 - Diseñe una serie de 25 valores que al ser insertados en la estructura (BST o AVL) demanden el peor de los escenarios.
#
# 3.3.a - Programáticamente, realice las 25 operaciones de insert en el BST creado en el inciso *3.1.a*, midiendo el tiempo de ejecución con la función proporcionada. Guarde los resultados en una lista.
#
# 3.3.b - Programáticamente, realice las mismas 25 operaciones de insert en el AVL creado en el inciso *3.1.b*, midiendo el tiempo de ejecución con la función proporcionada. Guarde los resultados en una lista.
#
# 3.4 - Utilizando los 25 tiempos registrados para el BST y AVL, calcule el promedio de *insert()* para cada tipo de árbol. Almacene estos dos valores ya que serán utilizados luego.

# %%
# Espacio para incisos 3.2 - 3.4 (utilizar cuantas celdas de código sean necesarias)

#3.2
worst_case_values_5k = [5001 + i for i in range(25)]

# %%
#3.3a
bst5k_insert_times = []

for value in worst_case_values_5k:
    duration = time_function(bst5k.insert, value)
    bst5k_insert_times.append(duration)
# Out:
# Execution time: 0.0006515000 secs
# Execution time: 0.0006920000 secs
# Execution time: 0.0008946000 secs
# Execution time: 0.0005460000 secs
# Execution time: 0.0005243000 secs
# Execution time: 0.0005463000 secs
# Execution time: 0.0005156000 secs
# Execution time: 0.0005167000 secs
# Execution time: 0.0005394000 secs
# Execution time: 0.0005407000 secs
# Execution time: 0.0005098000 secs
# Execution time: 0.0005220000 secs
# Execution time: 0.0005072000 secs
# Execution time: 0.0005293000 secs
# Execution time: 0.0005170000 secs
# Execution time: 0.0005125000 secs
# Execution time: 0.0005221000 secs
# Execution time: 0.0004996000 secs
# Execution time: 0.0005036000 secs
# Execution time: 0.0005074000 secs
# Execution time: 0.0004939000 secs
# Execution time: 0.0005168000 secs
# Execution time: 0.0004972000 secs
# Execution time: 0.0005072000 secs
# Execution time: 0.0005209000 secs

# %%
#3.3b
avlt5k_insert_times = []

for value in worst_case_values_5k:
    duration = time_function(avlt5k.insert, value)
    avlt5k_insert_times.append(duration)
# Out:
# Execution time: 0.0000110000 secs
# Execution time: 0.0000103000 secs
# Execution time: 0.0000049000 secs
# Execution time: 0.0000044000 secs
# Execution time: 0.0000046000 secs
# Execution time: 0.0000042000 secs
# Execution time: 0.0000041000 secs
# Execution time: 0.0000042000 secs
# Execution time: 0.0000050000 secs
# Execution time: 0.0000045000 secs
# Execution time: 0.0000041000 secs
# Execution time: 0.0000042000 secs
# Execution time: 0.0000042000 secs
# Execution time: 0.0000042000 secs
# Execution time: 0.0000042000 secs
# Execution time: 0.0000041000 secs
# Execution time: 0.0000042000 secs
# Execution time: 0.0000041000 secs
# Execution time: 0.0000041000 secs
# Execution time: 0.0000041000 secs
# Execution time: 0.0000042000 secs
# Execution time: 0.0000041000 secs
# Execution time: 0.0000045000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000042000 secs

# %%
#3.4
fivek_avg_bst_insert_time = sum(bst5k_insert_times) / len(bst5k_insert_times)
fivek_avg_avl_insert_time = sum(avlt5k_insert_times) / len(avlt5k_insert_times)

print(f"Promedio BST: {fivek_avg_bst_insert_time:.10f} secs")
print(f"Promedio AVL: {fivek_avg_avl_insert_time:.10f} secs")
# Out:
# Promedio BST: 0.0005453440 secs
# Promedio AVL: 0.0000048000 secs

# %% [markdown]
# ##### **Search()**
#
# 3.5 - Diseñe una serie de 25 valores que al ser buscados en la estructura (BST o AVL) demanden el peor de los escenarios (no exista).
#
# 3.6.a - Programáticamente, realice las 25 operaciones de search en el BST creado en el inciso 3.1.a, midiendo el tiempo de ejecución con la función proporcionada. Guarde los resultados en una lista.
#
# 3.6.b - Programáticamente, realice las mismas 25 operaciones de search en el AVL creado en el inciso 3.1.b, midiendo el tiempo de ejecución con la función proporcionada. Guarde los resultados en una lista.
#
# 3.7 - Utilizando los 25 tiempos registrados para el BST y AVL, calcule el promedio de *search()* para cada tipo de árbol. Almacene estos dos valores ya que serán utilizados luego.

# %%
# Espacio para incisos 3.5 - 3.7 (utilizar cuantas celdas de código sean necesarias)

#3.5
worst_case_search_values_5k = [6000 + i for i in range(25)]

# %%
#3.6a
bst5k_search_times = []

for value in worst_case_search_values_5k:
    duration = time_function(bst5k.search, value)
    bst5k_search_times.append(duration)
# Out:
# Execution time: 0.0006418000 secs
# Execution time: 0.0006206000 secs
# Execution time: 0.0005878000 secs
# Execution time: 0.0005782000 secs
# Execution time: 0.0005764000 secs
# Execution time: 0.0005726000 secs
# Execution time: 0.0005640000 secs
# Execution time: 0.0005690000 secs
# Execution time: 0.0005881000 secs
# Execution time: 0.0005605000 secs
# Execution time: 0.0006458000 secs
# Execution time: 0.0005434000 secs
# Execution time: 0.0005767000 secs
# Execution time: 0.0006379000 secs
# Execution time: 0.0007612000 secs
# Execution time: 0.0005865000 secs
# Execution time: 0.0006358000 secs
# Execution time: 0.0005726000 secs
# Execution time: 0.0005541000 secs
# Execution time: 0.0005698000 secs
# Execution time: 0.0005674000 secs
# Execution time: 0.0005530000 secs
# Execution time: 0.0005621000 secs
# Execution time: 0.0005495000 secs
# Execution time: 0.0005387000 secs

# %%
#3.6b
avlt5k_search_times = []

for value in worst_case_search_values_5k:
    duration = time_function(avlt5k.search, value)
    avlt5k_search_times.append(duration)
# Out:
# Execution time: 0.0000040000 secs
# Execution time: 0.0000016000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000007000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000008000 secs

# %%
#3.7
fivek_avg_bst_search_time = sum(bst5k_search_times) / len(bst5k_search_times)
fivek_avg_avl_search_time = sum(avlt5k_search_times) / len(avlt5k_search_times)

print(f"Promedio búsqueda BST: {fivek_avg_bst_search_time:.10f} secs")
print(f"Promedio búsqueda AVL: {fivek_avg_avl_search_time:.10f} secs")
# Out:
# Promedio búsqueda BST: 0.0005885400 secs
# Promedio búsqueda AVL: 0.0000009920 secs

# %% [markdown]
# ##### **Otros valores de *N***
#
# 3.8 - Repita los incisos del *3.1* al *3.7* con las siguientes cantidades de *n*:
# * 10K nodos
# * 25k nodos

# %% [markdown]
# ##### **Insert() 10k**

# %%
# Espacio para inciso 3.8 (utilizar cuantas celdas de código sean necesarias)
bst10k = BinarySearchTree()
for i in range(1, 10001):
    bst10k.insert(i)

# %%
avlt10k = AVLTree()
for i in range(1, 10001):
    avlt10k.insert(i)

# %%
worst_case_values_10k = [10001 + i for i in range(25)]

# %%
bst10k_insert_times = []

for value in worst_case_values_10k:
    duration = time_function(bst10k.insert, value)
    bst10k_insert_times.append(duration)
# Out:
# Execution time: 0.0011897000 secs
# Execution time: 0.0010742000 secs
# Execution time: 0.0011136000 secs
# Execution time: 0.0010568000 secs
# Execution time: 0.0010474000 secs
# Execution time: 0.0010131000 secs
# Execution time: 0.0010251000 secs
# Execution time: 0.0010149000 secs
# Execution time: 0.0014346000 secs
# Execution time: 0.0010531000 secs
# Execution time: 0.0011045000 secs
# Execution time: 0.0010808000 secs
# Execution time: 0.0010200000 secs
# Execution time: 0.0011237000 secs
# Execution time: 0.0010469000 secs
# Execution time: 0.0010712000 secs
# Execution time: 0.0010546000 secs
# Execution time: 0.0010730000 secs
# Execution time: 0.0010349000 secs
# Execution time: 0.0010301000 secs
# Execution time: 0.0010108000 secs
# Execution time: 0.0010241000 secs
# Execution time: 0.0010164000 secs
# Execution time: 0.0010434000 secs
# Execution time: 0.0010081000 secs

# %%
avlt10k_insert_times = []

for value in worst_case_values_10k:
    duration = time_function(avlt10k.insert, value)
    avlt10k_insert_times.append(duration)
# Out:
# Execution time: 0.0000115000 secs
# Execution time: 0.0000104000 secs
# Execution time: 0.0000059000 secs
# Execution time: 0.0000052000 secs
# Execution time: 0.0000048000 secs
# Execution time: 0.0000042000 secs
# Execution time: 0.0000044000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000044000 secs
# Execution time: 0.0000045000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000044000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000042000 secs
# Execution time: 0.0000047000 secs
# Execution time: 0.0000045000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000044000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000043000 secs
# Execution time: 0.0000043000 secs

# %%
tenk_avg_bst_insert_time = sum(bst10k_insert_times) / len(bst10k_insert_times)
tenk_avg_avl_insert_time = sum(avlt10k_insert_times) / len(avlt10k_insert_times)

print(f"Promedio BST: {tenk_avg_bst_insert_time:.10f} secs")
print(f"Promedio AVL: {tenk_avg_avl_insert_time:.10f} secs")
# Out:
# Promedio BST: 0.0010706000 secs
# Promedio AVL: 0.0000049920 secs

# %% [markdown]
# ##### **Search() 10k**

# %%
worst_case_search_values_10k = [11000 + i for i in range(25)]

# %%
bst10k_search_times = []

for value in worst_case_search_values_10k:
    duration = time_function(bst10k.search, value)
    bst10k_search_times.append(duration)
# Out:
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000010000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000008000 secs
# Execution time: 0.0000009000 secs
# Execution time: 0.0000010000 secs

# %%
tfk_avg_bst_search_time = sum(bst25k_search_times) / len(bst25k_search_times)
tfk_avg_avl_search_time = sum(avlt25k_search_times) / len(avlt25k_search_times)

print(f"Promedio búsqueda BST: {tfk_avg_bst_search_time:.10f} secs")
print(f"Promedio búsqueda AVL: {tfk_avg_avl_search_time:.10f} secs")
# Out:
# Promedio búsqueda BST: 0.0029295560 secs
# Promedio búsqueda AVL: 0.0000011000 secs

# %% [markdown]
# #### **4 - Gráfica**
# ---
#
# Una vez realizados todos los puntos del inciso *3* correctamente, debería tener la siguiente información basada en tiempos promedio tanto para el **BST** como para el **AVL**:
#
# |Operación | N = 5K   | N = 10K  | N = 25K  |
# |----------|----------|----------|----------|
# | Insert() | x secs   | x secs   | x secs   |
# | Search() | x secs   | x secs   | x secs   |
#
# Importante: recuerde mantener la precisión de diez decimales en los registros de tiempo.
#
# 4.1 - Programáticamente unificar los resultados en el formato que necesite para una ejecución automática de los incisos siguientes.
#
# 4.2 - Crear una gráfica que ilustre la complejidad de la operación de *Insert()* tanto para BST como para AVL. Considerar que:
# * Debe ser una única gráfica que superponga los resultados del BST y el AVL
# * Las funciones de complejidad resultantes deben identificar correctamente el tipo de árbol al que pertenece
# * Debe graficar las funciones de complejidad con un color distinto
#
# 4.3 - Crear una gráfica que ilustre la complejidad de la operación de *Search()* tanto para BST como para AVL. Tener presente las mismas consideraciones que en el inciso *4.2*.
#
# Recuerde que el objetivo es evidenciar claramente que la complejidad de las estructuras corresponden a la teoría, o sea:
# * Binary Search Tree - $O(n)$
# * AVL Tree - $O(log_{2}n)$

# %%
# Espacio para incisos 4.1 - 4.3 (utilizar cuantas celdas de código sean necesarias)

# Resultados obtenidos (estos son ejemplos, deberías sustituirlos con tus resultados reales)
results_operations = {
    "n_values": [5000, 10000, 25000],
    "bst_insert": [fivek_avg_bst_insert_time, tenk_avg_bst_insert_time, tfk_avg_bst_insert_time],
    "avl_insert": [fivek_avg_avl_insert_time, tenk_avg_avl_insert_time, tfk_avg_avl_insert_time],
    "bst_search": [fivek_avg_bst_search_time, tenk_avg_bst_search_time, tfk_avg_bst_search_time],
    "avl_search": [fivek_avg_avl_search_time, tenk_avg_avl_search_time, tfk_avg_avl_search_time],
}

# %%
import matplotlib.pyplot as plt

# Extraer valores
n_vals = results_operations["n_values"]
bst_insert = results_operations["bst_insert"]
avl_insert = results_operations["avl_insert"]

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.plot(n_vals, bst_insert, marker='o', linestyle='-', color='red', label='BST Insert (O(n))')
plt.plot(n_vals, avl_insert, marker='o', linestyle='-', color='green', label='AVL Insert (O(log n))')

# Configuración visual
plt.title("Complejidad de Insert() - BST vs AVL", fontsize=14)
plt.xlabel("Cantidad de nodos (n)", fontsize=12)
plt.ylabel("Tiempo promedio de insert (segundos)", fontsize=12)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Extraer valores
bst_search = results_operations["bst_search"]
avl_search = results_operations["avl_search"]

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.plot(n_vals, bst_search, marker='o', linestyle='-', color='orange', label='BST Search (O(n))')
plt.plot(n_vals, avl_search, marker='o', linestyle='-', color='blue', label='AVL Search (O(log n))')

# Configuración visual
plt.title("Complejidad de Search() - BST vs AVL", fontsize=14)
plt.xlabel("Cantidad de nodos (n)", fontsize=12)
plt.ylabel("Tiempo promedio de search (segundos)", fontsize=12)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **5 - Gráficas de puntos extra**
# ---

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Suponiendo que ya tienes estos resultados:
n_vals = [5000, 10000, 25000]
bst_insert = [fivek_avg_bst_insert_time, tenk_avg_bst_insert_time, tfk_avg_bst_insert_time]
avl_insert = [fivek_avg_avl_insert_time, tenk_avg_avl_insert_time, tfk_avg_avl_insert_time]

# Crear figura y eje principal
fig, ax1 = plt.subplots(figsize=(10, 6))

# Eje Y izquierdo - BST
ax1.plot(n_vals, bst_insert, 'r-o', label='BST Insert (O(n))')
ax1.set_xlabel('Cantidad de nodos (n)', fontsize=12)
ax1.set_ylabel('Tiempo BST Insert (s)', color='red', fontsize=12)
ax1.tick_params(axis='y', labelcolor='red')

# Ajustar la escala de la Y para que sea decimal en lugar de notación científica
ax1.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:.8f}'))

# Eje Y derecho - AVL
ax2 = ax1.twinx()
ax2.plot(n_vals, avl_insert, 'g-o', label='AVL Insert (O(log n))')
ax2.set_ylabel('Tiempo AVL Insert (s)', color='green', fontsize=12)
ax2.tick_params(axis='y', labelcolor='green')

# Ajustar la escala de la Y para que sea decimal en lugar de notación científica
ax2.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:.8f}'))

# Título y leyendas
plt.title('Comparación de tiempos de Insert() - BST vs AVL', fontsize=14)
fig.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Resultados de búsqueda
bst_search = [fivek_avg_bst_search_time, tenk_avg_bst_search_time, tfk_avg_bst_search_time]
avl_search = [fivek_avg_avl_search_time, tenk_avg_avl_search_time, tfk_avg_avl_search_time]

# Crear figura y eje principal
fig, ax1 = plt.subplots(figsize=(10, 6))

# Eje Y izquierdo - BST
ax1.plot(n_vals, bst_search, 'orange', marker='o', label='BST Search (O(n))')
ax1.set_xlabel('Cantidad de nodos (n)', fontsize=12)
ax1.set_ylabel('Tiempo BST Search (s)', color='orange', fontsize=12)
ax1.tick_params(axis='y', labelcolor='orange')

# Ajustar la escala de la Y para que sea decimal en lugar de notación científica
ax1.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:.8f}'))

# Eje Y derecho - AVL
ax2 = ax1.twinx()
ax2.plot(n_vals, avl_search, 'blue', marker='o', label='AVL Search (O(log n))')
ax2.set_ylabel('Tiempo AVL Search (s)', color='blue', fontsize=12)
ax2.tick_params(axis='y', labelcolor='blue')

# Ajustar la escala de la Y para que sea decimal en lugar de notación científica
ax2.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{x:.8f}'))

# Título y leyendas
plt.title('Comparación de tiempos de Search() - BST vs AVL', fontsize=14)
fig.tight_layout()
plt.show()
